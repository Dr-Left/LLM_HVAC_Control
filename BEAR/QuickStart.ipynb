# %%
# !pip install "sb3_contrib>=2.0.0a1" --upgrade
# !pip install "stable_baselines3>=2.0.0a1" --upgrade
# !pip install pvlib
# Out:
# Requirement already satisfied: sb3_contrib>=2.0.0a1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (2.4.0a4)
# Requirement already satisfied: stable-baselines3<3.0,>=2.4.0a4 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from sb3_contrib>=2.0.0a1) (2.4.0a7)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (0.29.1)
# Requirement already satisfied: numpy<2.0,>=1.20 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2.4.1)
# Requirement already satisfied: cloudpickle in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.0.0)
# Requirement already satisfied: pandas in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2.2.3)
# Requirement already satisfied: matplotlib in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.9.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (8.5.0)
# Requirement already satisfied: filelock in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.16.1)
# Requirement already satisfied: sympy in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.13.3)
# Requirement already satisfied: networkx in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.2.1)
# Requirement already satisfied: jinja2 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.1.4)
# Requirement already satisfied: fsspec in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (12.6.77)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (2024.2)
# Requirement already satisfied: zipp>=3.20 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from jinja2->torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.4.0a4->sb3_contrib>=2.0.0a1) (1.3.0)
# Requirement already satisfied: stable_baselines3>=2.0.0a1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (2.4.0a7)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (0.29.1)
# Requirement already satisfied: numpy<2.0,>=1.20 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (2.4.1)
# Requirement already satisfied: cloudpickle in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (3.0.0)
# Requirement already satisfied: pandas in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (2.2.3)
# Requirement already satisfied: matplotlib in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from stable_baselines3>=2.0.0a1) (3.9.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3>=2.0.0a1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3>=2.0.0a1) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3>=2.0.0a1) (8.5.0)
# Requirement already satisfied: filelock in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (3.16.1)
# Requirement already satisfied: sympy in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (1.13.3)
# Requirement already satisfied: networkx in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (3.2.1)
# Requirement already satisfied: jinja2 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (3.1.4)
# Requirement already satisfied: fsspec in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from torch>=1.13->stable_baselines3>=2.0.0a1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3>=2.0.0a1) (12.6.77)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from matplotlib->stable_baselines3>=2.0.0a1) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas->stable_baselines3>=2.0.0a1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas->stable_baselines3>=2.0.0a1) (2024.2)
# Requirement already satisfied: zipp>=3.20 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable_baselines3>=2.0.0a1) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3>=2.0.0a1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from jinja2->torch>=1.13->stable_baselines3>=2.0.0a1) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from sympy->torch>=1.13->stable_baselines3>=2.0.0a1) (1.3.0)
# Requirement already satisfied: pvlib in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.19.3 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (2.2.3)
# Requirement already satisfied: pytz in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (2024.2)
# Requirement already satisfied: requests in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (1.13.1)
# Requirement already satisfied: h5py in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pvlib) (3.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas>=1.3.0->pvlib) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from pandas>=1.3.0->pvlib) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from requests->pvlib) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from requests->pvlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from requests->pvlib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from requests->pvlib) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /home/chris/anaconda3/envs/thesis/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->pvlib) (1.16.0)

# %% [markdown]
# ## Please following the instructions and **DO NOT** modify the example file in the shared drive! Download the folder "BEAR" and upload it to **your Drive** in "My Drive", then run the cells

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
cwd = os.getcwd()

os.chdir("gdrive/My Drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#       3 import os
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
from BEAR.Env.env_building  import BuildingEnvReal
from BEAR.Controller.MPC_Controller import MPCAgent
from BEAR.Utils.utils_building import ParameterGenerator,get_user_input
import numpy as np
import functools
import datetime
import os
import time
from collections import deque
import matplotlib.pyplot as plt

# %% [markdown]
# ##Test

# %% [markdown]
# We start by creating an environment with a OfficeSmall type building at Tucson, and setting the weather type as Hot Dry:

# %%
env = get_user_input()
numofhours=24
#Initialize
env.reset()
for i in range(numofhours):
    a = env.action_space.sample()#Randomly select an action
    obs, r, terminated, truncated, _ = env.step(a)#Return observation and reward
RandomController_state=env.statelist #Collect the state list
RandomController_action=env.actionlist #Collect the action list
env._get_info()
# Out:
# Invalid climate zone. Please try again.
# ###############All Zones from Ground############
# CORE_BOTTOM  [Zone index]:  0
# PERIMETER_BOT_ZN_3  [Zone index]:  1
# PERIMETER_BOT_ZN_2  [Zone index]:  2
# PERIMETER_BOT_ZN_1  [Zone index]:  3
# PERIMETER_BOT_ZN_4  [Zone index]:  4
# FIRSTFLOOR_PLENUM  [Zone index]:  5
# CORE_MID  [Zone index]:  6
# PERIMETER_MID_ZN_3  [Zone index]:  7
# PERIMETER_MID_ZN_2  [Zone index]:  8
# PERIMETER_MID_ZN_1  [Zone index]:  9
# PERIMETER_MID_ZN_4  [Zone index]:  10
# MIDFLOOR_PLENUM  [Zone index]:  11
# CORE_TOP  [Zone index]:  12
# PERIMETER_TOP_ZN_3  [Zone index]:  13
# PERIMETER_TOP_ZN_2  [Zone index]:  14
# PERIMETER_TOP_ZN_1  [Zone index]:  15
# PERIMETER_TOP_ZN_4  [Zone index]:  16
# TOPFLOOR_PLENUM  [Zone index]:  17
# ###################################################
# How would you like to modify the reward function?
# Enter 1 to use the default reward function.
# Enter 2 to customize weights of the default function.
# Enter 3 to fully customize the reward function.
# 1. Default reward function:
# This is based on the energy consumed and the deviation from the target
# temperature. It uses two weights to balance these factors:
#
# def default_reward_function(self, state, action, error, state_new):
#    reward = 0
#    reward_part1 = LA.norm(error, 2) * self.error_rate
#    reward_part2 = LA.norm(action, 2) * self.q_rate
#    reward -= reward_part1 + reward_part2
#    self._reward_breakdown['comfort_level'] -= reward_part1
#    self._reward_breakdown['power_consumption'] -= reward_part2
#    return reward
#
# 2. Customize weights of the default function:
# You can adjust the weights for energy penalty and temperature error
# penalty to change the balance of the reward.
#
# 3. Fully customize the reward function:
# Define your own function taking the current state, action, error, and
# new state as inputs. Here's a structure you can use:
#
# def my_custom_reward_function(self, state, action, error, state_new):
#    reward_part1 = ...
#    reward_part2 = ...
#    reward = reward_part1 + reward_part2
#    self._reward_breakdown['reward_part1'] -= reward_part1
#    self._reward_breakdown['reward_part2'] -= reward_part2
#    return reward
#
# Congratulations! You have successfully created an environment.
# {'zone_temperature': array([-0.17270407,  2.02566049, -5.0463131 ,  1.72991143, -5.28779306,
#          0.34296693,  2.62886983,  4.62869054,  0.92151095,  4.70462926,
#          2.28664697,  3.05245279,  5.37318694,  5.28270216,  3.27225615,
#          7.35053815,  4.05512075,  5.73774522]),
#  'reward_breakdown': {'comfort_level': -1960.2683909310483,
#   'power_consumption': -1.4472353610992432}}

# %%
RandomController_action[0]
# Out:
# array([-1343.7982,  1964.0427, -3777.8914, -7113.3667, -6875.5864,
#        -3613.5183,  6615.708 , -2597.1848, -6115.7935, -3519.7388,
#         2510.2476,  4863.8364,  6918.0894,  1489.8923, -7871.1196,
#        -7881.934 ,  5062.732 ,  6804.7686], dtype=float32)

# %% [markdown]
# With the new version updated, users can also customize the reward function now. A custom reward function is a function you define that takes the current state, the action, and the error (difference between target and actual temperature), and the new state as inputs, and returns a reward value. This reward value is used to guide the agent's learning.The function should be written on **reward_functions.py** in the folder **BEAR/Customize**. A sample reward function is shown here:

# %%
def my_custom_reward_function(self, state, action, error, state_new):
    # This is your default reward function
    # Initialize the reward
    reward = 0
    self.co2_rate=0.01
    self.temp_rate=0.01

    # Desired temperature range
    lower_temp = 18
    upper_temp = 22

    # Calculate the contribution of action to the reward
    action_contribution = LA.norm(action, 2) * self.q_rate
    reward -= action_contribution

    # Calculate the contribution of error to the reward
    error_contribution = LA.norm(error, 2) * self.error_rate
    reward -= error_contribution

    # Calculate the contribution of temperature deviation to the reward
    temp_deviation = np.sum(np.maximum(0, state_new - upper_temp) + np.maximum(0, lower_temp - state_new)) * self.temp_rate
    reward -= temp_deviation

    # Calculate the contribution of CO2 emissions to the reward
    co2_emission = LA.norm(action, 2) * self.co2_rate
    reward -= co2_emission

    self._reward_breakdown['action_contribution'] -= action_contribution
    self._reward_breakdown['error_contribution'] -= error_contribution
    self._reward_breakdown['temp_deviation'] -= temp_deviation
    self._reward_breakdown['co2_emission'] -= co2_emission
    return reward

# %% [markdown]
# For more advance users, you can directly modify the ParameterGenerator and BuildingEnvReal to customize your enviornment:

# %%
Parameter=ParameterGenerator('OfficeSmall','Hot_Dry','Tucson')  #Description of ParameterGenerator in bldg_utils.py
#Create environment
env = BuildingEnvReal(Parameter)
numofhours=24
#Initialize with user-defined indoor temperature
env.reset(options={'T_initial':np.array([18.24489859, 18.58710076, 18.47719682, 19.11476084, 19.59438163,15.39221207])})
for i in range(numofhours):
    a = env.action_space.sample()#Randomly select an action
    obs, r, terminated, truncated, _ = env.step(a)#Return observation and reward
RandomController_state=env.statelist #Collect the state list
RandomController_action=env.actionlist #Collect the action list
env._get_info()
# Out:
# ###############All Zones from Ground############
# CORE_ZN  [Zone index]:  0
# PERIMETER_ZN_1  [Zone index]:  1
# PERIMETER_ZN_2  [Zone index]:  2
# PERIMETER_ZN_3  [Zone index]:  3
# PERIMETER_ZN_4  [Zone index]:  4
# ATTIC  [Zone index]:  5
# ###################################################
# {'zone_temperature': array([11.50499167, 12.40483428, 21.07799206, 18.43007991, 15.58897709,
#         18.00433628]),
#  'reward_breakdown': {'comfort_level': -875.9832537353334,
#   'power_consumption': -0.8153920183181761}}

# %% [markdown]
# The state space:$$s_k=[T_1[k],T_2[k], ...,T_{M}[k],Q_p[k],T_G[k],T_{E}[k],Q_{ghi}[k]]$$
#
# The action space:$$a_k=[Q^z_{1}[k],Q^z_{2}[k],...,Q^z_{M}[k]]$$

# %%
obs_dim = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(obs_dim))
action_dim = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(action_dim))
upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]
print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
print('Sample State :', RandomController_state[0])
print('Sample Action :', RandomController_action[0])
# Out:
# Size of State Space ->  20
# Size of Action Space ->  6
# Max Value of Action ->  1.0
# Min Value of Action ->  -1.0
# Sample State : [18.24489859 18.58710076 18.47719682 19.11476084 19.59438163 15.39221207
#   5.6         0.          0.          0.          0.          0.
#   0.         20.9        -0.03714446 -0.03714446 -0.03714446 -0.03714446
#  -0.03714446 -0.03714446]
# Sample Action : [-5590.592   6761.589   1757.7975  3065.9058 -1750.4368 -2015.4384]

# %% [markdown]
# ###No Action

# %% [markdown]
# We first test the environment with no actions. Let's loop for 24 hours and plot the temperature and energy comsumption of each zones :

# %%
obs
# Out:
# array([11.50499167, 12.40483428, 21.07799206, 18.43007991, 15.58897709,
#        18.00433628,  4.        ,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        , 20.9       , -0.03335059,
#        -0.03335059, -0.03335059, -0.03335059, -0.03335059, -0.03335059])

# %%
numofhours=24
env.reset()
a=env.action_space.sample()
for i in range(numofhours):

    a = [0,0,0,0,0,0]
    obs, r, terminated, truncated, _ = env.step(a)
plt.plot(np.array(env.statelist)[:,:7])
plt.title('Our Model Temperature')

plt.xlabel('hours')
plt.ylabel('Celsius')

plt.legend(['South','East','North','West','Core','Plenum','Outside'],loc='lower right')
plt.show()
plt.plot(np.sum(np.abs(np.array(env.actionlist)),1))

plt.title('Our Model Power')
plt.xlabel('hours')
plt.ylabel('Watts')
plt.show()

# %%
print('zone temerature at 1 a.m. :', np.array(env.statelist)[1,:6])
# Out:
# zone temerature at 1 a.m. : [17.75179317 17.07085633 17.14668666 17.19433022 16.78964807 17.86825243]

# %% [markdown]
# ###MPC

# %% [markdown]
# Then we use a MPC controller and set each room at 22 degrees:

# %%
agent = MPCAgent(env,
                gamma=env.gamma,
                safety_margin=0.96, planning_steps=10)
env.reset()
numofhours=24
reward_total=0
for i in range(numofhours):
    a,s = agent.predict(env)
    obs, r, terminated, truncated, _ = env.step(a)
    reward_total+=r
print('total reward is: ',reward_total)
plt.plot(np.array(env.statelist)[:,:7])
plt.title('Our Model Temperature')

plt.xlabel('hours')
plt.ylabel('Celsius')
plt.legend(['South','East','North','West','Core','Plenum','Outside'],loc='lower right')
plt.show()
plt.plot(np.sum(np.abs(np.array(env.actionlist)),1))
plt.title('Our Model Power')
plt.xlabel('hours')
plt.ylabel('Watts')
plt.show()
MPCstate=env.statelist
MPCaction=env.actionlist
# Out:
# total reward is:  -0.19466647171182835

# %%
print('zone temerature:', np.array(env.statelist)[0,:6])
# Out:
# zone temerature: [22. 22. 22. 22. 22. 22.]

# %%
plt.plot(np.array(env.actionlist))
plt.legend(['South','East','North','West','Core','Plenum','Outside'],loc='lower right')
#plt.ylim([0,50])
plt.show()

# %% [markdown]
# ### Reinforcement Learning

# %% [markdown]
# Finally, we use a PPO controller to demonstrate RL usage. We perform a quick train with default settings and save the model:

# %%
from stable_baselines3 import PPO ,DQN,DDPG
from stable_baselines3.common.logger import configure
from stable_baselines3.ppo import MlpPolicy
# from stable_baselines.bench import Monitor
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.env_util import make_vec_env

# %%
import torch
cuda_available = torch.cuda.is_available()
print("CUDA available:", cuda_available)
# Out:
# CUDA available: True

# %%
seed=0
env.reset()
set_random_seed(seed=seed)
model = PPO(MlpPolicy, env, verbose=1)
rewardlist=[]
action_record=[]

for i in range(100):
  model.learn(total_timesteps=1000)
  rw=0
  vec_env = model.get_env()
  obs = vec_env.reset()
  for i in range(24):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    rw+=rewards
  print(rw/24)
  rewardlist.append(rw/24)
  action_record.append(np.array(env.actionlist).sum(axis=1))
print("################TRAINING is Done############")
model.save("PPO_quick")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 334  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-33.111595]
# -----------------------------
# | time/              |      |
# |    fps             | 793  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-22.463072]
# -----------------------------
# | time/              |      |
# |    fps             | 763  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-30.207443]
# -----------------------------
# | time/              |      |
# |    fps             | 810  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-25.941156]
# -----------------------------
# | time/              |      |
# |    fps             | 792  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.507227]
# -----------------------------
# | time/              |      |
# |    fps             | 819  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.252123]
# -----------------------------
# | time/              |      |
# |    fps             | 778  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.548948]
# -----------------------------
# | time/              |      |
# |    fps             | 822  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.650908]
# -----------------------------
# | time/              |      |
# |    fps             | 818  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-25.474707]
# -----------------------------
# | time/              |      |
# |    fps             | 777  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.176498]
# -----------------------------
# | time/              |      |
# |    fps             | 801  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-26.989204]
# -----------------------------
# | time/              |      |
# |    fps             | 830  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.266207]
# -----------------------------
# | time/              |      |
# |    fps             | 823  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.240576]
# -----------------------------
# | time/              |      |
# |    fps             | 850  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-22.669024]
# -----------------------------
# | time/              |      |
# |    fps             | 774  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-24.578867]
# -----------------------------
# | time/              |      |
# |    fps             | 770  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-23.176918]
# -----------------------------
# | time/              |      |
# |    fps             | 770  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-20.948877]
# -----------------------------
# | time/              |      |
# |    fps             | 790  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-22.299097]
# -----------------------------
# | time/              |      |
# |    fps             | 765  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-23.275667]
# -----------------------------
# | time/              |      |
# |    fps             | 781  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-22.772423]
# -----------------------------
# | time/              |      |
# |    fps             | 790  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-23.438398]
# -----------------------------
# | time/              |      |
# |    fps             | 757  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-25.406439]
# -----------------------------
# | time/              |      |
# |    fps             | 769  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-23.612612]
# -----------------------------
# | time/              |      |
# |    fps             | 809  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-20.544413]
# -----------------------------
# | time/              |      |
# |    fps             | 803  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-23.643929]
# -----------------------------
# | time/              |      |
# |    fps             | 787  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-17.72949]
# -----------------------------
# | time/              |      |
# |    fps             | 755  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-20.447449]
# -----------------------------
# | time/              |      |
# |    fps             | 789  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.084276]
# -----------------------------
# | time/              |      |
# |    fps             | 747  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-19.729828]
# -----------------------------
# | time/              |      |
# |    fps             | 796  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-18.263609]
# -----------------------------
# | time/              |      |
# |    fps             | 775  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-18.266077]
# -----------------------------
# | time/              |      |
# |    fps             | 727  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-15.691537]
# -----------------------------
# | time/              |      |
# |    fps             | 776  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-20.799288]
# -----------------------------
# | time/              |      |
# |    fps             | 694  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-21.019629]
# -----------------------------
# | time/              |      |
# |    fps             | 750  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-18.960323]
# -----------------------------
# | time/              |      |
# |    fps             | 783  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.665789]
# -----------------------------
# | time/              |      |
# |    fps             | 786  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.257008]
# -----------------------------
# | time/              |      |
# |    fps             | 767  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-15.201291]
# -----------------------------
# | time/              |      |
# |    fps             | 789  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-21.227812]
# -----------------------------
# | time/              |      |
# |    fps             | 772  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-17.201635]
# -----------------------------
# | time/              |      |
# |    fps             | 784  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-18.381002]
# -----------------------------
# | time/              |      |
# |    fps             | 783  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-15.998123]
# -----------------------------
# | time/              |      |
# |    fps             | 700  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-19.773472]
# -----------------------------
# | time/              |      |
# |    fps             | 790  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-17.140047]
# -----------------------------
# | time/              |      |
# |    fps             | 812  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.378122]
# -----------------------------
# | time/              |      |
# |    fps             | 813  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-18.213041]
# -----------------------------
# | time/              |      |
# |    fps             | 789  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.093464]
# -----------------------------
# | time/              |      |
# |    fps             | 814  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-17.057705]
# -----------------------------
# | time/              |      |
# |    fps             | 822  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-15.4572935]
# -----------------------------
# | time/              |      |
# |    fps             | 853  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-14.375964]
# -----------------------------
# | time/              |      |
# |    fps             | 785  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-11.158862]
# -----------------------------
# | time/              |      |
# |    fps             | 836  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.290155]
# -----------------------------
# | time/              |      |
# |    fps             | 799  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-13.183868]
# -----------------------------
# | time/              |      |
# |    fps             | 808  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-13.122668]
# -----------------------------
# | time/              |      |
# |    fps             | 785  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-14.388715]
# -----------------------------
# | time/              |      |
# |    fps             | 854  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-16.175219]
# -----------------------------
# | time/              |      |
# |    fps             | 798  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-15.56771]
# -----------------------------
# | time/              |      |
# |    fps             | 812  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-12.645236]
# -----------------------------
# | time/              |      |
# |    fps             | 788  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-10.746975]
# -----------------------------
# | time/              |      |
# |    fps             | 820  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-14.254807]
# -----------------------------
# | time/              |      |
# |    fps             | 748  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-11.716377]
# -----------------------------
# | time/              |      |
# |    fps             | 795  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-10.639219]
# -----------------------------
# | time/              |      |
# |    fps             | 813  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-10.803741]
# -----------------------------
# | time/              |      |
# |    fps             | 803  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-13.650757]
# -----------------------------
# | time/              |      |
# |    fps             | 602  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-11.788957]
# -----------------------------
# | time/              |      |
# |    fps             | 766  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-12.49447]
# -----------------------------
# | time/              |      |
# |    fps             | 820  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-13.431565]
# -----------------------------
# | time/              |      |
# |    fps             | 785  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-13.280807]
# -----------------------------
# | time/              |      |
# |    fps             | 794  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-11.426289]
# -----------------------------
# | time/              |      |
# |    fps             | 808  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-12.003804]
# -----------------------------
# | time/              |      |
# |    fps             | 843  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-10.814556]
# -----------------------------
# | time/              |      |
# |    fps             | 810  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.542438]
# -----------------------------
# | time/              |      |
# |    fps             | 829  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-12.420715]
# -----------------------------
# | time/              |      |
# |    fps             | 856  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.758445]
# -----------------------------
# | time/              |      |
# |    fps             | 843  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.232539]
# -----------------------------
# | time/              |      |
# |    fps             | 744  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.676558]
# -----------------------------
# | time/              |      |
# |    fps             | 811  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-8.6708145]
# -----------------------------
# | time/              |      |
# |    fps             | 809  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.156073]
# -----------------------------
# | time/              |      |
# |    fps             | 831  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.366721]
# -----------------------------
# | time/              |      |
# |    fps             | 742  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.031709]
# -----------------------------
# | time/              |      |
# |    fps             | 824  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-9.612849]
# -----------------------------
# | time/              |      |
# |    fps             | 786  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-8.367585]
# -----------------------------
# | time/              |      |
# |    fps             | 793  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-8.87382]
# -----------------------------
# | time/              |      |
# |    fps             | 770  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.950807]
# -----------------------------
# | time/              |      |
# |    fps             | 767  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.4001203]
# -----------------------------
# | time/              |      |
# |    fps             | 784  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.527289]
# -----------------------------
# | time/              |      |
# |    fps             | 805  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.3052597]
# -----------------------------
# | time/              |      |
# |    fps             | 830  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.8628826]
# -----------------------------
# | time/              |      |
# |    fps             | 844  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.9606667]
# -----------------------------
# | time/              |      |
# |    fps             | 825  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.5832458]
# -----------------------------
# | time/              |      |
# |    fps             | 820  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.1766677]
# -----------------------------
# | time/              |      |
# |    fps             | 781  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.4489403]
# -----------------------------
# | time/              |      |
# |    fps             | 814  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.174812]
# -----------------------------
# | time/              |      |
# |    fps             | 822  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-5.6028504]
# -----------------------------
# | time/              |      |
# |    fps             | 769  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.729261]
# -----------------------------
# | time/              |      |
# |    fps             | 783  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.5815296]
# -----------------------------
# | time/              |      |
# |    fps             | 830  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.5546417]
# -----------------------------
# | time/              |      |
# |    fps             | 779  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-7.4673676]
# -----------------------------
# | time/              |      |
# |    fps             | 779  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-6.3765354]
# -----------------------------
# | time/              |      |
# |    fps             | 864  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# [-5.797695]
# ################TRAINING is Done############

# %% [markdown]
# Then, we load the model and see the performance of the state and action:

# %%
model = PPO(MlpPolicy, env, verbose=1)
vec_env = model.get_env()
model = PPO.load("PPO_quick")
obs = vec_env.reset()
print("Initial observation", obs)

for i in range(24):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
plt.plot(np.array(env.statelist)[:,:7])
plt.title('Our Model Temperature')

plt.xlabel('hours')
plt.ylabel('Celsius')
plt.legend(['South','East','North','West','Core','Plenum','Outside'],loc='lower right')
plt.show()
plt.plot(np.sum(np.abs(np.array(env.actionlist)),1))
plt.title('Our Model Power')
plt.xlabel('hours')
plt.ylabel('Watts')
plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Initial observation [[22.         22.         22.         22.         22.         22.
#    5.6         0.          0.          0.          0.          0.
#    0.         20.9        -0.07856952 -0.07856952 -0.07856952 -0.07856952
#   -0.07856952 -0.07856952]]

# %%
plt.title('Quick PPO training')
plt.plot(rewardlist)
plt.xlabel('episode')
plt.ylabel('reward')
plt.show()

# %%
env.close()
